# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

#Load in csv
pyberRide_df=pd.read_csv("../Resources/PyBer_ride_data.csv")
pyberRide_df
# Out:
#     Month  Avg. Fare ($USD)
# 0     Jan             10.02
# 1     Feb             23.24
# 2     Mar             39.20
# 3   April             35.42
# 4     May             32.34
# 5    June             27.04
# 6    July             43.82
# 7     Aug             10.56
# 8    Sept             11.85
# 9     Oct             27.90
# 10    Nov             20.71
# 11    Dec             20.09

# %%
# Set x-axis and tick locations
x_axis = np.arange(len(pyberRide_df))
tick_locations= [value for value in x_axis]

# Plot the data

pyberRide_df.plot(x="Month", y="Avg. Fare ($USD)")

plt.xticks(tick_locations, pyberRide_df["Month"])
plt.show()

# %%
pyberRide_df.plot.bar(x="Month", y="Avg. Fare ($USD)")
plt.show()

# %%
import matplotlib.pyplot as plt
import statistics
# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

pyberRide_df.plot(x="Month", y="Avg. Fare ($USD)", kind='bar', rot=0, color='xkcd:sky blue')
plt.yticks(np.arange(0,51,step=5.0))
plt.errorbar(x_axis, y_axis, capsize=3,yerr=stdev, c='k')
plt.show()

# %%
# Out:
# <ErrorbarContainer object of 3 artists>
